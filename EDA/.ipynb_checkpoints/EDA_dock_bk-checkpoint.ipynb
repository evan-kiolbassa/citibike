# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from string import ascii_letters
import seaborn as sns


# import plotly.express as px
# import plotly.graph_objects as go
# px.set_mapbox_access_token(open('mapbox_token.txt').read())

# %%
tripdata_raw = pd.read_csv('/Users/bkuo/Local Documents/Bootcamp 2020/Project/Capstone/CitiBikeCapStone/Data/Trip data/202011-citibike-tripdata.csv')

# %%
tripdata_raw.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           521  2020-11-01 00:00:07.0150  2020-11-01 00:08:48.3010
# 1           492  2020-11-01 00:00:10.8080  2020-11-01 00:08:23.3170
# 2          1979  2020-11-01 00:00:14.7040  2020-11-01 00:33:14.1640
# 3          2382  2020-11-01 00:00:14.7070  2020-11-01 00:39:57.0030
# 4           166  2020-11-01 00:00:15.9690  2020-11-01 00:03:02.8980
#
#    start station id      start station name  start station latitude  \
# 0              3467  W Broadway & Spring St               40.724947
# 1              3557           40 Ave & 9 St               40.757420
# 2              3085    Roebling St & N 4 St               40.714690
# 3              3783    Cliff St & Fulton St               40.708380
# 4               422        W 59 St & 10 Ave               40.770513
#
#    start station longitude  end station id          end station name  \
# 0               -74.001659             350     Clinton St & Grand St
# 1               -73.945133            3557             40 Ave & 9 St
# 2               -73.957390            3854  Morgan Ave & Maspeth Ave
# 3               -74.004950            3167   Amsterdam Ave & W 73 St
# 4               -73.988038            3175   W 70 St & Amsterdam Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.715595             -73.987030   40405  Subscriber
# 1             40.757420             -73.945133   46504  Subscriber
# 2             40.716657             -73.936370   37452  Subscriber
# 3             40.779668             -73.980930   40417  Subscriber
# 4             40.777480             -73.982886   35776  Subscriber
#
#    birth year  gender
# 0        1989       1
# 1        1970       2
# 2        1989       2
# 3        1981       1
# 4        1990       1

# %%
# stn_dist.to_csv('station_distance')

# %%
# dock station status
stations_cleaned = pd.read_csv('/Users/bkuo/Local Documents/Bootcamp 2020/Project/Capstone/CitiBikeCapStone/Data/Dock station data/stations_cleaned.csv')
#             delim_whitespace = True)
stations_cleaned.head()
# Out:
# /Users/bkuo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    dock_id         dock_name        date  hour  minute  avail_bikes  \
# 0       72  W 52 St & 11 Ave  2015-03-01     1       6            8
# 1       72  W 52 St & 11 Ave  2015-03-01     1      16            8
# 2       72  W 52 St & 11 Ave  2015-03-01     1      25            8
# 3       72  W 52 St & 11 Ave  2015-03-01     1      35            8
# 4       72  W 52 St & 11 Ave  2015-03-01     1      45            8
#
#    avail_docks  tot_docks       _lat      _long  in_service status_key  \
# 0           31         39  40.767272 -73.993929           1          1
# 1           31         39  40.767272 -73.993929           1          1
# 2           30         38  40.767272 -73.993929           1          1
# 3           30         38  40.767272 -73.993929           1          1
# 4           30         38  40.767272 -73.993929           1          1
#
#    dock_status  time  dayofweek dayofweek2  season
# 0  Empty Alert   1:6          6     Sunday  spring
# 1  Empty Alert  1:16          6     Sunday  spring
# 2  Empty Alert  1:25          6     Sunday  spring
# 3  Empty Alert  1:35          6     Sunday  spring
# 4  Empty Alert  1:45          6     Sunday  spring

# %%
dock = stations_cleaned.copy()
# dock['hour24'] = dock.hour
# dock[dock['hour24'] != 12].loc[dock.pm == 1, 'hour24'] = dock.hour24 + 12
dock.hour = dock.hour.astype(str).apply(lambda x: x.zfill(2))
dock.loc[dock['hour'] == '24', 'hour'] = '00'
dock.minute = dock.minute.astype(str).apply(lambda x: x.zfill(2))
dock['time'] = dock.hour + ':' + dock.minute + ':' +  '00'
dock['datetime'] = pd.to_datetime(dock['date'] + ' ' + dock['time'])
dock = dock.drop(['date', 'hour', 'minute', 'time'], axis = 1)
dock.head()
# Out:
#    dock_id         dock_name  avail_bikes  avail_docks  tot_docks       _lat  \
# 0       72  W 52 St & 11 Ave            8           31         39  40.767272
# 1       72  W 52 St & 11 Ave            8           31         39  40.767272
# 2       72  W 52 St & 11 Ave            8           30         38  40.767272
# 3       72  W 52 St & 11 Ave            8           30         38  40.767272
# 4       72  W 52 St & 11 Ave            8           30         38  40.767272
#
#        _long  in_service status_key  dock_status  dayofweek dayofweek2  \
# 0 -73.993929           1          1  Empty Alert          6     Sunday
# 1 -73.993929           1          1  Empty Alert          6     Sunday
# 2 -73.993929           1          1  Empty Alert          6     Sunday
# 3 -73.993929           1          1  Empty Alert          6     Sunday
# 4 -73.993929           1          1  Empty Alert          6     Sunday
#
#    season            datetime
# 0  spring 2015-03-01 01:06:00
# 1  spring 2015-03-01 01:16:00
# 2  spring 2015-03-01 01:25:00
# 3  spring 2015-03-01 01:35:00
# 4  spring 2015-03-01 01:45:00

# %%
dock.describe()
# Out:
#             dock_id   avail_bikes   avail_docks     tot_docks          _lat  \
# count  3.239142e+07  3.239142e+07  3.239142e+07  3.239142e+07  3.239142e+07
# mean   1.505113e+03  1.121125e+01  1.963295e+01  3.179422e+01  4.072800e+01
# std    1.365721e+03  1.063801e+01  1.338239e+01  1.175093e+01  7.818515e-02
# min    7.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.600000e+02  2.000000e+00  9.000000e+00  2.400000e+01  4.070531e+01
# 50%    4.950000e+02  8.000000e+00  1.800000e+01  3.100000e+01  4.072521e+01
# 75%    3.132000e+03  1.800000e+01  2.800000e+01  3.900000e+01  4.075038e+01
# max    3.534000e+03  1.160000e+02  7.900000e+01  9.800000e+01  4.407427e+02
#
#               _long    in_service     dayofweek
# count  3.239142e+07  3.239142e+07  3.239142e+07
# mean  -7.398373e+01  9.560140e-01  3.025526e+00
# std    1.073389e-01  2.050640e-01  1.984087e+00
# min   -7.409694e+01  0.000000e+00  0.000000e+00
# 25%   -7.399695e+01  1.000000e+00  1.000000e+00
# 50%   -7.398336e+01  1.000000e+00  3.000000e+00
# 75%   -7.396592e+01  1.000000e+00  5.000000e+00
# max    7.397713e+01  1.000000e+00  6.000000e+00

# %%
#dock.to_csv('stations_more_clean')

# %%
stations_more_clean = pd.read_csv('stations_more_clean')
stations_more_clean.head()
# Out:
# /Users/bkuo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  dock_id         dock_name  avail_bikes  avail_docks  tot_docks  \
# 0           0       72  W 52 St & 11 Ave            8           31         39
# 1           1       72  W 52 St & 11 Ave            8           31         39
# 2           2       72  W 52 St & 11 Ave            8           30         38
# 3           3       72  W 52 St & 11 Ave            8           30         38
# 4           4       72  W 52 St & 11 Ave            8           30         38
#
#         _lat      _long  in_service status_key  dock_status  dayofweek  \
# 0  40.767272 -73.993929           1          1  Empty Alert          6
# 1  40.767272 -73.993929           1          1  Empty Alert          6
# 2  40.767272 -73.993929           1          1  Empty Alert          6
# 3  40.767272 -73.993929           1          1  Empty Alert          6
# 4  40.767272 -73.993929           1          1  Empty Alert          6
#
#   dayofweek2  season             datetime
# 0     Sunday  spring  2015-03-01 01:06:00
# 1     Sunday  spring  2015-03-01 01:16:00
# 2     Sunday  spring  2015-03-01 01:25:00
# 3     Sunday  spring  2015-03-01 01:35:00
# 4     Sunday  spring  2015-03-01 01:45:00

# %%
dock = stations_more_clean
dock = dock.drop(['Unnamed: 0', '_lat', '_long'], axis = 1)
dock.datetime= pd.to_datetime(dock.datetime)

# %%
dock['perc_bike_avail'] = dock.avail_bikes/dock.tot_docks

# %%
# downsample:
#dock = dock.sample(frac = 0.1, replace=True)

# %%
# smaller time frame:
# start_date = '01-01-2018'
# end_date = '12-31-2018'
# mask = (dock['datetime'] > start_date) & (dock['datetime'] <= end_date)
# dock = dock.loc[mask]

# %%
# time of days
time_of_day = dock.copy()
time_of_day = time_of_day[['datetime','perc_bike_avail']]
time_of_day['hour'] = time_of_day['datetime'].dt.hour
time_of_day['peak'] = [1 if time > 5 and time < 20 else 0 for time in time_of_day.hour]

# %%
# bike availability during peak (median value)

bka = time_of_day[['perc_bike_avail', 'hour', 'peak']].groupby('hour').median()
bka = bka.reset_index()
sns.barplot(data = bka, x = 'hour', y = "perc_bike_avail", hue = 'peak' )

# g.sns.set(rc={'figure.figsize':(12,8)})

# %%
# day of week

# plt = dock[['dayofweek2', 'perc_bike_avail']].groupby('dayofweek2').median()

sns.boxplot(data = dock, x = 'dayofweek2', y = "perc_bike_avail")

# %%
# day of week median availability excluding 2015
dock_no2015 = dock[dock['datetime'].dt.year != 2015]
sns.boxplot(data = dock_no2015, x = 'dayofweek2', y = "perc_bike_avail")

# %%
# seasonal bike number
sns.boxplot(data = dock, x = 'season', y = "avail_bikes")
avail_docks

# %%
dock.columns
# Out:
# Index(['dock_id', 'dock_name', 'avail_bikes', 'avail_docks', 'tot_docks',
#        'in_service', 'status_key', 'dock_status', 'dayofweek', 'dayofweek2',
#        'season', 'datetime', 'perc_bike_avail'],
#       dtype='object')

# %%
# seasonal dock number
season = dock.copy()
season['year'] = season.datetime.dt.year
sns.scatterplot(data = season, x = 'year', y = "avail_docks", hue = 'season')

# %%
# season availability ex 2015
sns.boxplot(data = dock_no2015, x = 'season', y = "perc_bike_avail")

# %%
# yearly comparison
yr = dock[['datetime', 'perc_bike_avail']]
yr['year']= yr.datetime.dt.year
sns.boxplot(data = yr, x = 'year', y = "perc_bike_avail")
# Out:
# /Users/bkuo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# yearly comparison no 2015
yr = dock_no2015[['datetime', 'perc_bike_avail']]
yr['year']= yr.datetime.dt.year
sns.boxplot(data = yr, x = 'year', y = "perc_bike_avail")
# Out:
# /Users/bkuo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# # sns.set_theme(style="white")

# # Generate a large random dataset

# d = pd.DataFrame(dock,
#                  columns=list(ascii_letters[26:]))

# # Compute the correlation matrix
# corr = d.corr()

# # Generate a mask for the upper triangle
# mask = np.triu(np.ones_like(corr, dtype=bool))

# # Set up the matplotlib figure
# f, ax = plt.subplots(figsize=(11, 9))

# # Generate a custom diverging colormap
# cmap = sns.diverging_palette(230, 20, as_cmap=True)

# # Draw the heatmap with the mask and correct aspect ratio
# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
#             square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# daily average of bikes/docks
mday = dock.groupby(pd.Grouper(key="datetime", freq="D"))\
    .agg({'avail_bikes':'mean',
          'avail_docks':'mean'})
df = mday

# day vs available bikes
sns.lineplot(data=df, x=df.index, y=df.avail_bikes)
plt.xticks(rotation=45)
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# daily total bikes/docks
day = dock.groupby(pd.Grouper(key="datetime", freq="D"))\
    .agg({'avail_bikes':'sum',
          'avail_docks':'sum',
          'tot_docks':'sum'})
df = day

# day vs available bikes
sns.lineplot(data=df, x=df.index, y=df.avail_bikes)
plt.xticks(rotation=45)


# fig = px.bar(df, x = df.index, y = "avail_bikes")
# fig.show()
# fig = px.bar(df, x = df.index, y = "avail_docks")
# fig.show()
# fig = px.bar(df, x = df.index, y = "tot_docks")
# fig.show()
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# day vs available docks
sns.lineplot(data=df, x=df.index, y=df.avail_docks)
plt.xticks(rotation=45)
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# day vs total docks
sns.lineplot(data=df, x=df.index, y=df.tot_docks)
plt.xticks(rotation=45)
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# week
wk = dock.groupby(pd.Grouper(key = "datetime", freq="W"))\
    .agg({'avail_bikes':'sum',
          'avail_docks':'sum',
          'tot_docks':'sum'})
df = wk

# week vs. total docks
sns.lineplot(data=df, x=df.index, y=df.avail_bikes)
plt.xticks(rotation=45)

# fig = px.bar(df, x = df.index, y = "avail_bikes")
# fig.show()
# fig = px.bar(df, x = df.index, y = "avail_docks")
# fig.show()
# fig = px.bar(df, x = df.index, y = "tot_docks")
# fig.show()
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# week vs available docks
sns.lineplot(data=df, x=df.index, y=df.avail_docks)
plt.xticks(rotation=45)
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# week vs total docks
sns.lineplot(data=df, x=df.index, y=df.tot_docks)
plt.xticks(rotation=30)
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# month
month = dock.groupby(pd.Grouper(key="datetime", freq="M"))\
    .agg({'avail_bikes':'sum',
         'avail_docks':'sum',
         'tot_docks':'sum',
          'perc_bike_avail':'mean'})
df = month

# %%
sns.lineplot(data=df, x=df.index, y=df.avail_bikes)
plt.xticks(rotation=30)
# Out:
# (array([735780., 735964., 736146., 736330., 736511., 736695., 736876.,
#         737060., 737241.]), <a list of 9 Text xticklabel objects>)

# %%
sns.lineplot(data=df, x=df.index, y=df.avail_docks)
plt.xticks(rotation=30)
# Out:
# (array([735780., 735964., 736146., 736330., 736511., 736695., 736876.,
#         737060., 737241.]), <a list of 9 Text xticklabel objects>)

# %%
sns.lineplot(data=df, x=df.index, y=df.tot_docks)
plt.xticks(rotation=30)
# Out:
# (array([735780., 735964., 736146., 736330., 736511., 736695., 736876.,
#         737060., 737241.]), <a list of 9 Text xticklabel objects>)

# %%
sns.lineplot(data=df, x=df.index, y=df.perc_bike_avail)
plt.xticks(rotation=30)
# Out:
# (array([735719., 735903., 736085., 736269., 736450., 736634., 736815.,
#         736999., 737180.]), <a list of 9 Text xticklabel objects>)

# %%
# year
yr = dock.groupby(pd.Grouper(key="datetime", freq="Y"))\
    .agg({'avail_bikes':'sum',
          'avail_docks':'sum',
          'tot_docks':'sum',
          'perc_bike_avail':'mean'})
df = yr
# fig = px.bar(df, x = df.index, y = "avail_bikes")
# fig.show()
# fig = px.bar(df, x = df.index, y = "avail_docks")
# fig.show()
# fig = px.bar(df, x = df.index, y = "tot_docks")
# fig.show()

# %%
sns.lineplot(data=df, x=df.index, y=df.avail_bikes)
plt.xticks(rotation=30)
# Out:
# (array([735903., 736085., 736269., 736450., 736634., 736815., 736999.,
#         737180., 737364.]), <a list of 9 Text xticklabel objects>)

# %%
sns.lineplot(data=df, x=df.index, y=df.avail_docks)
plt.xticks(rotation=30)
# Out:
# (array([735903., 736085., 736269., 736450., 736634., 736815., 736999.,
#         737180., 737364.]), <a list of 9 Text xticklabel objects>)

# %%
sns.lineplot(data=df, x=df.index, y=df.tot_docks)
plt.xticks(rotation=30)
# Out:
# (array([735903., 736085., 736269., 736450., 736634., 736815., 736999.,
#         737180., 737364.]), <a list of 9 Text xticklabel objects>)

# %%
sns.lineplot(data=df, x=df.index, y=df.perc_bike_avail)
plt.xticks(rotation=30)
# Out:
# (array([736389., 736511., 736634., 736754., 736876., 736999., 737119.,
#         737241., 737364.]), <a list of 9 Text xticklabel objects>)

# %%
# real time station status 
url = 'https://gbfs.citibikenyc.com/gbfs/fr/station_status.json'

station_status = pd.read_json(path_or_buf = url)
station_status = pd.DataFrame(station_status.data[0])

# %%
station_status.head()#[['station_id', 'num_docks_available']]
# Out:
#    eightd_has_available_keys  is_installed  is_renting  is_returning  \
# 0                      False             1           1             1
# 1                      False             1           1             1
# 2                      False             1           1             1
# 3                      False             1           1             1
# 4                      False             1           1             1
#
#    last_reported legacy_id  num_bikes_available  num_bikes_disabled  \
# 0     1607676544        72                   10                   1
# 1     1607670918        79                   19                   1
# 2     1607669418        82                   13                   3
# 3     1607668211        83                   34                   1
# 4     1607670625       116                   17                   2
#
#    num_docks_available  num_docks_disabled  num_ebikes_available station_id  \
# 0                   44                   0                     2         72
# 1                   13                   0                     2         79
# 2                   11                   0                     2         82
# 3                   27                   0                     0         83
# 4                   31                   0                     2        116
#
#   station_status
# 0         active
# 1         active
# 2         active
# 3         active
# 4         active

# %%
station_status[station_status.station_status == 'active'][['station_id', 'num_docks_available']].shape
# Out:
# (1208, 2)

# %%
# free_bike_status - no info
url = 'https://gbfs.citibikenyc.com/gbfs/fr/free_bike_status.json'
free_bike_status = pd.read_json(path_or_buf = url)
free_bike_status
# Out:
#       data  last_updated  ttl
# bikes   []    1607681800    5

# %%
# staion information
url = 'https://gbfs.citibikenyc.com/gbfs/fr/station_information.json'
station_info = pd.read_json(path_or_buf = url)
station_info = pd.DataFrame(station_info.data[0])
station_info
# Out:
#       capacity  eightd_has_key_dispenser eightd_station_services  \
# 0           55                     False                      []
# 1           33                     False                      []
# 2           27                     False                      []
# 3           62                     False                      []
# 4           50                     False                      []
# 5           53                     False                      []
# 6           19                     False                      []
# 7           31                     False                      []
# 8           56                     False                      []
# 9           24                     False                      []
# 10          58                     False                      []
# 11          39                     False                      []
# 12          55                     False                      []
# 13          33                      True                      []
# 14          49                     False                      []
# 15          23                     False                      []
# 16          35                     False                      []
# 17          47                     False                      []
# 18          47                     False                      []
# 19          70                     False                      []
# 20          35                     False                      []
# 21          60                     False                      []
# 22          37                     False                      []
# 23          39                     False                      []
# 24          33                     False                      []
# 25          34                      True                      []
# 26          55                     False                      []
# 27          23                     False                      []
# 28          51                     False                      []
# 29          39                     False                      []
# ...        ...                       ...                     ...
# 1184        19                     False                      []
# 1185        27                     False                      []
# 1186        19                     False                      []
# 1187        19                     False                      []
# 1188        18                     False                      []
# 1189        24                     False                      []
# 1190        19                     False                      []
# 1191        19                     False                      []
# 1192        19                     False                      []
# 1193        28                     False                      []
# 1194        32                     False                      []
# 1195        27                     False                      []
# 1196        27                     False                      []
# 1197        33                     False                      []
# 1198        19                     False                      []
# 1199        19                     False                      []
# 1200        24                     False                      []
# 1201        19                     False                      []
# 1202        45                     False                      []
# 1203        55                     False                      []
# 1204        59                     False                      []
# 1205        79                     False                      []
# 1206        25                     False                      []
# 1207        24                     False                      []
# 1208        21                     False                      []
# 1209        63                     False                      []
# 1210        25                     False                      []
# 1211        19                     False                      []
# 1212         0                     False                      []
# 1213         0                     False                      []
#
#       electric_bike_surcharge_waiver                           external_id  \
# 0                              False  66db237e-0aca-11e7-82f6-3863bb44ef7c
# 1                              False  66db269c-0aca-11e7-82f6-3863bb44ef7c
# 2                              False  66db277a-0aca-11e7-82f6-3863bb44ef7c
# 3                              False  66db281e-0aca-11e7-82f6-3863bb44ef7c
# 4                              False  66db28b5-0aca-11e7-82f6-3863bb44ef7c
# 5                              False  66db2953-0aca-11e7-82f6-3863bb44ef7c
# 6                              False  66db29e6-0aca-11e7-82f6-3863bb44ef7c
# 7                              False  66db2a71-0aca-11e7-82f6-3863bb44ef7c
# 8                              False  66db2afe-0aca-11e7-82f6-3863bb44ef7c
# 9                              False  66db2d2b-0aca-11e7-82f6-3863bb44ef7c
# 10                             False  66db2db5-0aca-11e7-82f6-3863bb44ef7c
# 11                             False  66db2e3a-0aca-11e7-82f6-3863bb44ef7c
# 12                             False  66db2f4c-0aca-11e7-82f6-3863bb44ef7c
# 13                             False  66db2fd0-0aca-11e7-82f6-3863bb44ef7c
# 14                             False  66db3053-0aca-11e7-82f6-3863bb44ef7c
# 15                             False  66db316a-0aca-11e7-82f6-3863bb44ef7c
# 16                             False  66db3273-0aca-11e7-82f6-3863bb44ef7c
# 17                             False  66db32fb-0aca-11e7-82f6-3863bb44ef7c
# 18                             False  66db33fc-0aca-11e7-82f6-3863bb44ef7c
# 19                             False  66db347b-0aca-11e7-82f6-3863bb44ef7c
# 20                             False  66db34fc-0aca-11e7-82f6-3863bb44ef7c
# 21                             False  66db3606-0aca-11e7-82f6-3863bb44ef7c
# 22                             False  66db3687-0aca-11e7-82f6-3863bb44ef7c
# 23                             False  66db3708-0aca-11e7-82f6-3863bb44ef7c
# 24                             False  66db3816-0aca-11e7-82f6-3863bb44ef7c
# 25                             False  66db3898-0aca-11e7-82f6-3863bb44ef7c
# 26                             False  66db3997-0aca-11e7-82f6-3863bb44ef7c
# 27                             False  66db3a1e-0aca-11e7-82f6-3863bb44ef7c
# 28                             False  66db3ba0-0aca-11e7-82f6-3863bb44ef7c
# 29                             False  66db3c29-0aca-11e7-82f6-3863bb44ef7c
# ...                              ...                                   ...
# 1184                           False  c809158b-ca8f-4a77-a800-8ee9d287c056
# 1185                           False  7938263e-e5b8-4ca7-b8bf-1adbaae5fead
# 1186                           False  6fd84197-56e2-47df-849f-701aca0e7cc3
# 1187                           False  dee5a590-7cda-465e-8351-b0622a5e2ad3
# 1188                           False  ba7bf20d-b6bc-43dd-bf30-acb940eaeec8
# 1189                           False  b4ae292d-5e89-4c58-8154-0496893394b5
# 1190                           False  c0e0e578-8ce8-4c9d-be47-b902d8a41050
# 1191                           False  fea72f55-d296-47af-9446-149688dcccbd
# 1192                           False  068b919c-f649-4091-8e12-ccf37191cad5
# 1193                           False  0c923abb-298a-4a47-b132-9fae73cc59e6
# 1194                           False  05c5e17c-7aa9-49b7-9da3-9db4858ec1fc
# 1195                           False  943be327-0320-4ae1-8eb0-8a56f86a4fb6
# 1196                           False  141eb0e0-e78d-411a-a0be-202a6424cc93
# 1197                           False  cbf76774-1276-4cf8-9442-f00571f1451c
# 1198                           False  426862de-f8f2-4967-ba41-76680a4b460c
# 1199                           False  55146e49-9bc4-4f13-bdf7-25422342b638
# 1200                           False  cb4926e6-0a79-4902-80ee-d365fbf42aec
# 1201                           False  9790606b-a00d-4d5e-b6ec-abd11c9d25b3
# 1202                           False  904930bd-2671-4695-9c1a-8a894b041129
# 1203                           False  88e64257-298c-4b8d-8886-77b9b66dcec1
# 1204                           False  1f872052-38c4-4701-96c4-c363de51c2b5
# 1205                           False  2c321ea3-e1dd-4d32-be70-bd158fe1f568
# 1206                           False  70634bc4-4d90-42d4-8f6a-3f29fa8f7f77
# 1207                           False  11d5b3a4-fb27-490e-86c7-0836c58f15f9
# 1208                           False  4aa6bb27-b76b-444e-a3ce-6fb25b822494
# 1209                           False  ff2869f0-4381-4cf3-863e-a0d776ec53b4
# 1210                           False  c4d6b123-df5a-446d-b0ae-d3c4846565d5
# 1211                           False  c602146e-d69d-43b6-9e8f-054c4df5377e
# 1212                           False  83a5d761-57d0-4cd6-aa2b-7eb350120d99
# 1213                           False  23dddc4c-dcce-4a9a-a244-c2fab8b4a0fe
#
#       has_kiosk        lat legacy_id        lon  \
# 0          True  40.767272        72 -73.993929
# 1          True  40.719116        79 -74.006667
# 2          True  40.711174        82 -74.000165
# 3          True  40.683826        83 -73.976323
# 4          True  40.741776       116 -74.001497
# 5          True  40.696089       119 -73.978034
# 6          True  40.686768       120 -73.959282
# 7          True  40.731724       127 -74.006744
# 8          True  40.727103       128 -74.002971
# 9          True  40.692395       143 -73.993379
# 10         True  40.698399       144 -73.980689
# 11         True  40.716250       146 -74.009106
# 12         True  40.720874       150 -73.980858
# 13         True  40.722104       151 -73.997249
# 14         True  40.714740       152 -74.009106
# 15         True  40.690893       157 -73.996123
# 16         True  40.729170       161 -73.998102
# 17         True  40.753231       164 -73.970325
# 18         True  40.739713       168 -73.994564
# 19         True  40.760683       173 -73.984527
# 20         True  40.738177       174 -73.977387
# 21         True  40.743349       212 -74.006818
# 22         True  40.700379       216 -73.995481
# 23         True  40.702772       217 -73.993836
# 24         True  40.737815       223 -73.999947
# 25         True  40.711464       224 -74.005524
# 26         True  40.754601       228 -73.971879
# 27         True  40.727434       229 -73.993790
# 28         True  40.728419       236 -73.987140
# 29         True  40.730473       237 -73.986724
# ...         ...        ...       ...        ...
# 1184       True  40.841092      4205 -73.892317
# 1185       True  40.811892      4206 -73.904192
# 1186       True  40.831305      4207 -73.917448
# 1187       True  40.822351      4208 -73.926907
# 1188       True  40.838706      4209 -73.927034
# 1189       True  40.831960      4210 -73.919560
# 1190       True  40.829950      4211 -73.898802
# 1191       True  40.831710      4212 -73.902080
# 1192       True  40.835302      4213 -73.895133
# 1193       True  40.740057      4215 -74.005274
# 1194       True  40.754145      4219 -73.996089
# 1195       True  40.823061      4220 -73.941928
# 1196       True  40.822217      4222 -73.928939
# 1197       True  40.696233      4225 -73.991421
# 1198       True  40.837037      4227 -73.890413
# 1199       True  40.839194      4228 -73.888587
# 1200       True  40.840494      4229 -73.911479
# 1201       True  40.835877      4230 -73.893143
# 1202       True  40.756951      4232 -73.982631
# 1203       True  40.764734      4235 -73.991944
# 1204       True  40.768333      4236 -73.992573
# 1205       True  40.762009      4238 -73.996975
# 1206       True  40.757334      4239 -73.974235
# 1207       True  40.821952      4245 -73.888546
# 1208       True  40.832164      4247 -73.949702
# 1209       True  40.703367      4248 -74.007868
# 1210       True  40.836179      4249 -73.907301
# 1211       True  40.818726      4250 -73.888625
# 1212      False  40.827629      4252 -73.886659
# 1213      False  40.823926      4253 -73.897366
#
#                                     name region_id     rental_methods  \
# 0                       W 52 St & 11 Ave        71  [CREDITCARD, KEY]
# 1               Franklin St & W Broadway        71  [CREDITCARD, KEY]
# 2                 St James Pl & Pearl St        71  [CREDITCARD, KEY]
# 3          Atlantic Ave & Fort Greene Pl        71  [CREDITCARD, KEY]
# 4                        W 17 St & 8 Ave        71  [CREDITCARD, KEY]
# 5               Park Ave & St Edwards St        71  [CREDITCARD, KEY]
# 6            Lexington Ave & Classon Ave        71  [CREDITCARD, KEY]
# 7                  Barrow St & Hudson St        71  [CREDITCARD, KEY]
# 8               MacDougal St & Prince St        71  [CREDITCARD, KEY]
# 9              Clinton St & Joralemon St        71  [CREDITCARD, KEY]
# 10                   Nassau St & Navy St        71  [CREDITCARD, KEY]
# 11                  Hudson St & Reade St        71  [CREDITCARD, KEY]
# 12                     E 2 St & Avenue C        71  [CREDITCARD, KEY]
# 13              Cleveland Pl & Spring St        71  [CREDITCARD, KEY]
# 14                Warren St & W Broadway        71  [CREDITCARD, KEY]
# 15               Henry St & Atlantic Ave        71  [CREDITCARD, KEY]
# 16                 LaGuardia Pl & W 3 St        71  [CREDITCARD, KEY]
# 17                       E 47 St & 2 Ave        71  [CREDITCARD, KEY]
# 18                       W 18 St & 6 Ave        71  [CREDITCARD, KEY]
# 19                    Broadway & W 49 St        71  [CREDITCARD, KEY]
# 20                       E 25 St & 1 Ave        71  [CREDITCARD, KEY]
# 21               W 16 St & The High Line        71  [CREDITCARD, KEY]
# 22       Columbia Heights & Cranberry St        71  [CREDITCARD, KEY]
# 23                         Old Fulton St        71  [CREDITCARD, KEY]
# 24                       W 13 St & 7 Ave        71  [CREDITCARD, KEY]
# 25                 Spruce St & Nassau St        71  [CREDITCARD, KEY]
# 26                       E 48 St & 3 Ave        71  [CREDITCARD, KEY]
# 27                        Great Jones St        71  [CREDITCARD, KEY]
# 28                   St Marks Pl & 2 Ave        71  [CREDITCARD, KEY]
# 29                       E 11 St & 2 Ave        71  [CREDITCARD, KEY]
# ...                                  ...       ...                ...
# 1184   Crotona Park North & Prospect Ave        71  [CREDITCARD, KEY]
# 1185            Southern Blvd & E 149 St        71  [CREDITCARD, KEY]
# 1186              Sherman Ave & E 166 St        71  [CREDITCARD, KEY]
# 1187               Walton Ave & E 153 St        71  [CREDITCARD, KEY]
# 1188           University Ave & W 168 St        71  [CREDITCARD, KEY]
# 1189          Grand Concourse & E 166 St        71  [CREDITCARD, KEY]
# 1190                Union Ave & E 169 St        71  [CREDITCARD, KEY]
# 1191             Franklin Ave & E 169 St        71  [CREDITCARD, KEY]
# 1192        Wilkins Ave & Crotona Park E        71  [CREDITCARD, KEY]
# 1193                 Hudson St & W 13 St        71  [CREDITCARD, KEY]
# 1194                     W 35 St & 9 Ave        71  [CREDITCARD, KEY]
# 1195  Frederick Douglass Blvd & W 145 St        71  [CREDITCARD, KEY]
# 1196                River Ave & E 151 St        71  [CREDITCARD, KEY]
# 1197             Clinton St & Tillary St        71  [CREDITCARD, KEY]
# 1198        Crotona Park East & E 173 St        71  [CREDITCARD, KEY]
# 1199     Waterloo Pl & Crotona Park East        71  [CREDITCARD, KEY]
# 1200             Sheridan Ave & E 172 St        71  [CREDITCARD, KEY]
# 1201            Charlotte St & Boston Rd        71  [CREDITCARD, KEY]
# 1202                     6 Ave & W 45 St        71  [CREDITCARD, KEY]
# 1203                    W 50 St & 10 Ave        71  [CREDITCARD, KEY]
# 1204                    W 54 St & 11 Ave        71  [CREDITCARD, KEY]
# 1205                    W 44 St & 11 Ave        71  [CREDITCARD, KEY]
# 1206                  E 50 St & Park Ave        71  [CREDITCARD, KEY]
# 1207          Bruckner Blvd & Bryant Ave        71  [CREDITCARD, KEY]
# 1208             Riverside Dr & W 153 St        71  [CREDITCARD, KEY]
# 1209                 Old Slip & South St        71  [CREDITCARD, KEY]
# 1210              E 170 St & Webster Ave        71  [CREDITCARD, KEY]
# 1211              Seneca Ave & Irvine St        71  [CREDITCARD, KEY]
# 1212           Home St & Westchester Ave        71  [CREDITCARD, KEY]
# 1213                Rogers Pl & E 165 St        71  [CREDITCARD, KEY]
#
#                                              rental_url short_name station_id  \
# 0     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6926.01         72
# 1     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5430.08         79
# 2     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5167.06         82
# 3     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4354.07         83
# 4     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6148.02        116
# 5     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4700.06        119
# 6     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4452.03        120
# 7     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5805.05        127
# 8     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5687.04        128
# 9     http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4605.04        143
# 10    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4812.02        144
# 11    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5359.10        146
# 12    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5476.03        150
# 13    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5492.05        151
# 14    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5288.09        152
# 15    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4531.05        157
# 16    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5721.14        161
# 17    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6498.10        164
# 18    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6064.08        168
# 19    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6708.02        173
# 20    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6004.07        174
# 21    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6233.05        212
# 22    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4829.01        216
# 23    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4903.08        217
# 24    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6030.04        223
# 25    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5137.10        224
# 26    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6541.03        228
# 27    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5636.11        229
# 28    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5669.10        236
# 29    http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    5746.04        237
# ...                                                 ...        ...        ...
# 1184  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8236.01       4205
# 1185  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    7788.13       4206
# 1186  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8072.06       4207
# 1187  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    7945.07       4208
# 1188  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8183.02       4209
# 1189  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8092.06       4210
# 1190  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8064.03       4211
# 1191  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8118.02       4212
# 1192  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8167.02       4213
# 1193  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6115.06       4215
# 1194  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6569.09       4219
# 1195  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    7954.12       4220
# 1196  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    7967.04       4222
# 1197  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4748.07       4225
# 1198  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8182.02       4227
# 1199  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8216.02       4228
# 1200  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8229.04       4229
# 1201  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8167.04       4230
# 1202  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6593.15       4232
# 1203  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6890.06       4235
# 1204  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6955.05       4236
# 1205  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6756.05       4238
# 1206  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    6659.10       4239
# 1207  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    7944.11       4245
# 1208  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8108.02       4247
# 1209  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    4993.13       4248
# 1210  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8156.03       4249
# 1211  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    7883.09       4250
# 1212  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    8020.01       4252
# 1213  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...    7987.07       4253
#
#      station_type
# 0         classic
# 1         classic
# 2         classic
# 3         classic
# 4         classic
# 5         classic
# 6         classic
# 7         classic
# 8         classic
# 9         classic
# 10        classic
# 11        classic
# 12        classic
# 13        classic
# 14        classic
# 15        classic
# 16        classic
# 17        classic
# 18        classic
# 19        classic
# 20        classic
# 21        classic
# 22        classic
# 23        classic
# 24        classic
# 25        classic
# 26        classic
# 27        classic
# 28        classic
# 29        classic
# ...           ...
# 1184      classic
# 1185      classic
# 1186      classic
# 1187      classic
# 1188      classic
# 1189      classic
# 1190      classic
# 1191      classic
# 1192      classic
# 1193      classic
# 1194      classic
# 1195      classic
# 1196      classic
# 1197      classic
# 1198      classic
# 1199      classic
# 1200      classic
# 1201      classic
# 1202      classic
# 1203      classic
# 1204      classic
# 1205      classic
# 1206      classic
# 1207      classic
# 1208      classic
# 1209      classic
# 1210      classic
# 1211      classic
# 1212      classic
# 1213      classic
#
# [1214 rows x 16 columns]
