# %%
import numpy as np
import pandas as pd
import dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
import swifter
import pickle
import re

# %%
riders = pd.read_csv('../data/output.csv',\
                     usecols = ['tripduration','starttime','stoptime','start station id', 'start station name',\
                               'end station id', 'bikeid'],\
                     parse_dates = ['starttime', 'stoptime'],\
                     dtype = {'start station id': 'Int32', 'end station id': 'Int32'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in month(self, name)
#     336         try:
# --> 337             return self._months[name.lower()] + 1
#     338         except KeyError:
#
# KeyError: '2016'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-68ca550884ab> in <module>
#       3                                'end station id', 'bikeid'],\
#       4                      parse_dates = ['starttime', 'stoptime'],\
# ----> 5                      dtype = {'start station id': 'Int32', 'end station id': 'Int32'})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2230             data = {k: v for k, (i, v) in zip(names, data)}
#    2231
# -> 2232             names, data = self._do_date_conversions(names, data)
#    2233             index, names = self._make_index(data, alldata, names)
#    2234
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _do_date_conversions(self, names, data)
#    1970                 self.index_names,
#    1971                 names,
# -> 1972                 keep_date_col=self.keep_date_col,
#    1973             )
#    1974
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    3413                 if _isindex(colspec):
#    3414                     continue
# -> 3415                 data_dict[colspec] = converter(data_dict[colspec])
#    3416             else:
#    3417                 new_name, col, old_names = _try_convert_dates(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3349                     errors="ignore",
#    3350                     infer_datetime_format=infer_datetime_format,
# -> 3351                     cache=cache_dates,
#    3352                 ).to_numpy()
#    3353
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     826             result = _convert_and_box_cache(arg, cache_array)
#     827         else:
# --> 828             result = convert_listlike(arg, format)
#     829     else:
#     830         result = convert_listlike(np.array([arg]), format)[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     464             errors=errors,
#     465             require_iso8601=require_iso8601,
# --> 466             allow_object=True,
#     467         )
#     468
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2048             dayfirst=dayfirst,
#    2049             yearfirst=yearfirst,
# -> 2050             require_iso8601=require_iso8601,
#    2051         )
#    2052     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     644                                                       second=0, microsecond=0)
#     645
# --> 646         res, skipped_tokens = self._parse(timestr, **kwargs)
#     647
#     648         if res is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in _parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     744                 if value is not None:
#     745                     # Numeric token
# --> 746                     i = self._parse_numeric_token(l, i, info, ymd, res, fuzzy)
#     747
#     748                 # Check weekday
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in _parse_numeric_token(self, tokens, idx, info, ymd, res, fuzzy)
#     974                 if idx + 3 < len_l and tokens[idx + 3] == sep:
#     975                     # We have three members
# --> 976                     value = info.month(tokens[idx + 4])
#     977
#     978                     if value is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in month(self, name)
#     335     def month(self, name):
#     336         try:
# --> 337             return self._months[name.lower()] + 1
#     338         except KeyError:
#     339             pass
#
# KeyboardInterrupt:

# %%
riders.head(5)
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           362 2017-09-01 00:00:17 2017-09-01 00:06:19              3331
# 1           188 2017-09-01 00:00:21 2017-09-01 00:03:30              3101
# 2           305 2017-09-01 00:00:25 2017-09-01 00:05:30              3140
# 3           223 2017-09-01 00:00:52 2017-09-01 00:04:36               236
# 4           758 2017-09-01 00:01:01 2017-09-01 00:13:40              3427
#
#          start station name  end station id  bikeid
# 0   Riverside Dr & W 104 St            3328   14530
# 1     N 12 St & Bedford Ave            3100   15475
# 2           1 Ave & E 78 St            3141   30346
# 3       St Marks Pl & 2 Ave             473   28056
# 4  Lafayette St & Jersey St            3431   25413

# %%
def cleaning_ridersdata(df):
    
    """This function will clean the riders data.
    The data cleaning function contains several new features.
    """
    
    df.starttime.astype('M8[us]')
    df.stoptime.astype('M8[us]')
    
    # Drop missing values
    df = df.dropna(subset=['start station id', 'end station id']).reset_index()
    
    # create year column
    df['year'] = df.starttime.dt.year
    print('completed year column')
    
    # create date column
    df['start_date'] = df.starttime.dt.date
    df['stop_date'] = df.stoptime.dt.date
    print('completed date column')
    
    # create hour column
    df['start_hour'] = df.starttime.dt.hour
    df['stop_hour'] = df.stoptime.dt.hour
    print('completed hour column')
    
    # create minutes column
    df['start_min'] = df.starttime.dt.minute
    df['stop_min'] = df.starttime.dt.minute
    print('completed minutes column')
    
    # For easier computation and analysis, we decided to round the minutes by 30 minutes time frame
    df['start_min'] = df['start_min'].apply(lambda x: 0 if x < 30 else 30)
    df['stop_min'] = df['stop_min'].apply(lambda x: 0 if x < 30 else 30)
    
    
    # create season column
    df['season'] = df.starttime.dt.month.apply(lambda x: 4 if x <= 2 else 1 if x <= 5 else \
    2 if x <= 8 else 3 if x <= 11 else 4')
    print('completed season column')
    
    # create day of week column
    df['dayofweek'] = df['starttime'].dt.weekday.apply(lambda x: 0 if x == 0 else 1 if x==1 else \
    2 if x == 2 else 3 if x == 3 else 4 if x == 4 else 5 if x == 5 else 6)
    print('completed week column')
    
    # create interval column
    df['start_interval'] = df.apply(lambda x: str(x['start_hour']) + ":" + str(x['start_min']), axis=1)
    df['stop_interval'] = df.apply(lambda x: str(x['stop_hour']) + ":" + str(x['stop_min']), axis=1)

# %%
riders.to_csv("../Data/riders_cleaned.csv")

# %%
cleaning_ridersdata(riders)
# Out:
# completed year column
# completed date column
# completed hour column
# completed minutes column
# completed season column
# completed week column

# %%
riders = pd.read_csv('../data/riders_cleaned.csv.gz',\
                    usecols = ['tripduration','starttime','stoptime','start station id', 'start station name',\
                               'end station id', 'bikeid', 'start_date', 'stop_date', 'start_hour', 'season',\
                              'stop_hour', 'start_min', 'stop_min','dayofweek'],\
                     dtype = {'start station id': 'Int32', 'end station id': 'Int32'})

# %%
riders.dtypes
# Out:
# tripduration           int64
# starttime             object
# stoptime              object
# start station id       Int32
# start station name    object
# end station id         Int32
# bikeid                 int64
# start_date            object
# stop_date             object
# start_hour             int64
# stop_hour              int64
# start_min              int64
# stop_min               int64
# dtype: object

# %%
riders
# Out:
#            tripduration                starttime                 stoptime  \
# 0                   362      2017-09-01 00:00:17      2017-09-01 00:06:19
# 1                   188      2017-09-01 00:00:21      2017-09-01 00:03:30
# 2                   305      2017-09-01 00:00:25      2017-09-01 00:05:30
# 3                   223      2017-09-01 00:00:52      2017-09-01 00:04:36
# 4                   758      2017-09-01 00:01:01      2017-09-01 00:13:40
# ...                 ...                      ...                      ...
# 110341608          1587  2020-01-31 23:59:26.882  2020-02-01 00:25:54.489
# 110341609           222  2020-01-31 23:59:32.641  2020-02-01 00:03:15.472
# 110341610           163  2020-01-31 23:59:39.178  2020-02-01 00:02:23.040
# 110341611           327  2020-01-31 23:59:49.231  2020-02-01 00:05:16.379
# 110341612           484  2020-01-31 23:59:57.036  2020-02-01 00:08:01.182
#
#            start station id          start station name  end station id  \
# 0                      3331     Riverside Dr & W 104 St            3328
# 1                      3101       N 12 St & Bedford Ave            3100
# 2                      3140             1 Ave & E 78 St            3141
# 3                       236         St Marks Pl & 2 Ave             473
# 4                      3427    Lafayette St & Jersey St            3431
# ...                     ...                         ...             ...
# 110341608              3244      University Pl & E 8 St            3092
# 110341609               383  Greenwich Ave & Charles St             383
# 110341610               150           E 2 St & Avenue C             411
# 110341611               483             E 12 St & 3 Ave            3718
# 110341612               327    Vesey Pl & River Terrace             534
#
#            bikeid  start_date   stop_date  start_hour  stop_hour  start_min  \
# 0           14530  2017-09-01  2017-09-01           0          0          0
# 1           15475  2017-09-01  2017-09-01           0          0          0
# 2           30346  2017-09-01  2017-09-01           0          0          0
# 3           28056  2017-09-01  2017-09-01           0          0          0
# 4           25413  2017-09-01  2017-09-01           0          0          0
# ...           ...         ...         ...         ...        ...        ...
# 110341608   40662  2020-01-31  2020-02-01          23          0         40
# 110341609   28722  2020-01-31  2020-02-01          23          0         40
# 110341610   32530  2020-01-31  2020-02-01          23          0         40
# 110341611   15314  2020-01-31  2020-02-01          23          0         40
# 110341612   30947  2020-01-31  2020-02-01          23          0         40
#
#            stop_min  season dayofweek
# 0                 0    fall    Friday
# 1                 0    fall    Friday
# 2                 0    fall    Friday
# 3                 0    fall    Friday
# 4                 0    fall    Friday
# ...             ...     ...       ...
# 110341608        40  winter    Friday
# 110341609        40  winter    Friday
# 110341610        40  winter    Friday
# 110341611        40  winter    Friday
# 110341612        40  winter    Friday
#
# [110341613 rows x 15 columns]

# %%
# A function that creates a dataframe that aggregates a bike demands in a hour interval
def create_outgoing_rides(df):
    outgoing_rides = df.groupby(['start station id','start_date','season','dayofweek','start_hour'])\
    [['starttime']].count().reset_index().rename(columns={'starttime':'outgoing_bike_count'})
        
    print('completed first job')
        
    return outgoing_rides

# %%
outgoing = create_outgoing_rides(riders)
# Out:
# completed first job

# %%
outgoing
# Out:
#           start station id  start_date  season dayofweek  start_hour  \
# 0                       72  2013-06-01  summer  Saturday           0
# 1                       72  2013-06-01  summer  Saturday           7
# 2                       72  2013-06-01  summer  Saturday           8
# 3                       72  2013-06-01  summer  Saturday          10
# 4                       72  2013-06-01  summer  Saturday          11
# ...                    ...         ...     ...       ...         ...
# 22289226              4249  2020-11-30    fall    Monday          17
# 22289227              4249  2020-11-30    fall    Monday          18
# 22289228              4249  2020-11-30    fall    Monday          19
# 22289229              4249  2020-11-30    fall    Monday          20
# 22289230              4249  2020-11-30    fall    Monday          21
#
#           outgoing_bike_count
# 0                           1
# 1                           1
# 2                           2
# 3                           1
# 4                           1
# ...                       ...
# 22289226                    1
# 22289227                    1
# 22289228                    2
# 22289229                    2
# 22289230                    1
#
# [22289231 rows x 6 columns]

# %%
outgoing.outgoing_bike_count.describe()['75%']
# Out:
# 6.0

# %%
outgoing.outgoing_bike_count.describe()['25%']
# Out:
# 1.0

# %%
outgoing['bike_demand'] = outgoing['outgoing_bike_count'].apply(lambda x: 'High' if x > 6 else \
'Medium' if x > 1 else 'Low')

# %%
outgoing.to_csv("../Data/outgoing.csv")

# %%
# A function that creates a dataframe that aggregates a dock demands in a hour interval
def create_incoming_rides(df):
    incoming_rides = df.groupby(['end station id','stop_date','season','dayofweek','stop_hour'])\
    [['stoptime']].count().reset_index().rename(columns={'stoptime':'incoming_bike_count'})
        
    print('completed first job')
    
    return incoming_rides

# %%
incoming = create_incoming_rides(riders)
# Out:
# completed first job

# %%
incoming.incoming_bike_count.describe()['75%']
# Out:
# 6.0

# %%
incoming['dock_demand'] = incoming['incoming_bike_count'].apply(lambda x: 'High' if x > 6 else \
'Medium' if x > 1 else 'Low')

# %%
incoming.to_csv("../Data/incoming.csv")
