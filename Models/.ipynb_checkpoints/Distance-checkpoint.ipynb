# %%
import pandas as pd
import numpy as np
import pickle

# %%
stations = pd.read_csv('../data/stations_cleaned.csv.gz')
# Out:
# /Users/danielchoy/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
stations
# Out:
#           dock_id                           dock_name        date  hour  \
# 0              72                    W 52 St & 11 Ave  2015-03-01     1
# 1              72                    W 52 St & 11 Ave  2015-03-01     1
# 2              72                    W 52 St & 11 Ave  2015-03-01     1
# 3              72                    W 52 St & 11 Ave  2015-03-01     1
# 4              72                    W 52 St & 11 Ave  2015-03-01     1
# ...           ...                                 ...         ...   ...
# 32391416     3534  Frederick Douglass Blvd & W 117 St  2019-01-31    21
# 32391417     3534  Frederick Douglass Blvd & W 117 St  2019-01-31    22
# 32391418     3534  Frederick Douglass Blvd & W 117 St  2019-01-31    22
# 32391419     3534  Frederick Douglass Blvd & W 117 St  2019-01-31    23
# 32391420     3534  Frederick Douglass Blvd & W 117 St  2019-01-31    24
#
#           minute  avail_bikes  avail_docks  tot_docks       _lat      _long  \
# ...

# %%
station_dict={}
for station in stations.dock_id.unique().tolist():
    loc1=(stations[stations.dock_id==station]._lat.values,stations[stations.dock_id==station]._long.values)
    others=[x for x in stations.dock_id.unique().tolist() if x != station]
    dist_to_others={}
    for othr_station in others:
        loc2=(stations[stations.dock_id==othr_station]._lat.values,stations[stations.dock_id==othr_station]._long.values)
        distance=(abs(loc1[0]-loc2[0])+abs(loc1[1]-loc2[1]))[0]
        dist_to_others[othr_station]=distance
    dist_to_others=sorted(dist_to_others.items(), key = lambda kv:(kv[1], kv[0])) 
    station_dict[station]=dist_to_others


output = open('station_dict.pkl', 'wb')
pickle.dump(station_dict, output, -1)
output.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0f593eba5b43> in <module>
#       6     for othr_station in others:
#       7         loc2=(stations[stations.dock_id==othr_station]._lat.values,stations[stations.dock_id==othr_station]._long.values)
# ----> 8         distance=(abs(loc1[0]-loc2[0])+abs(loc1[1]-loc2[1]))[0]
#       9         dist_to_others[othr_station]=distance
#      10     dist_to_others=sorted(dist_to_others.items(), key = lambda kv:(kv[1], kv[0])) # sort by smallest distance
#
# ValueError: operands could not be broadcast together with shapes (11607,) (13120,)
