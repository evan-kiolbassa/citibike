# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.neighbors import DistanceMetric
from math import radians

# %%
stations = pd.read_csv('../data/stations_cleaned.csv.gz')
# Out:
# /Users/danielchoy/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ride_stations = pd.read_csv('../data/riders_cleaned.csv.gz', usecols = ['start station id', 'start station name', 'start station latitude', 'start station longitude'])

# %%
ride_stations
# Out:
#            start station id          start station name  \
# 0                      3331     Riverside Dr & W 104 St
# 1                      3101       N 12 St & Bedford Ave
# 2                      3140             1 Ave & E 78 St
# 3                       236         St Marks Pl & 2 Ave
# 4                      3427    Lafayette St & Jersey St
# ...                     ...                         ...
# 110341608              3244      University Pl & E 8 St
# 110341609               383  Greenwich Ave & Charles St
# 110341610               150           E 2 St & Avenue C
# 110341611               483             E 12 St & 3 Ave
# 110341612               327    Vesey Pl & River Terrace
#
#            start station latitude  start station longitude
# 0                       40.801343               -73.971146
# 1                       40.720798               -73.954847
# 2                       40.771404               -73.953517
# ...

# %%
# Method 1
ride_stations_df = ride_stations.groupby('start station id')[['start station latitude', 'start station longitude']].mean().reset_index()

# %%
# Method 2
ride_stations_df = ride_stations.drop_duplicates(subset = ['start station id'])

# %%
ride_stations_df
# Out:
#            start station id                   start station name  \
# 0                      3331              Riverside Dr & W 104 St
# 1                      3101                N 12 St & Bedford Ave
# 2                      3140                      1 Ave & E 78 St
# 3                       236                  St Marks Pl & 2 Ave
# 4                      3427             Lafayette St & Jersey St
# ...                     ...                                  ...
# 104429750              3252  Bike The Branches - Red Hook Branch
# 106981303              3248                         LPI Facility
# 107204017              3215                        JSQ Don't Use
# 107204025              3480                         WS Don't Use
# 107210640              3197                         Hs Don't Use
#
#            start station latitude  start station longitude
# 0                       40.801343               -73.971146
# 1                       40.720798               -73.954847
# ...

# %%
ride_stations_df=ride_stations_df.rename(columns = {'start station id': 'dock_id'})

# %%
ride_stations_df = ride_stations_df.reset_index()

# %%
ride_stations_df = ride_stations_df.drop('index', axis = 1)

# %%
ride_stations_df
# Out:
#       dock_id                   start station name  start station latitude  \
# 0        3331              Riverside Dr & W 104 St               40.801343
# 1        3101                N 12 St & Bedford Ave               40.720798
# 2        3140                      1 Ave & E 78 St               40.771404
# 3         236                  St Marks Pl & 2 Ave               40.728419
# 4        3427             Lafayette St & Jersey St               40.724305
# ...       ...                                  ...                     ...
# 1355     3252  Bike The Branches - Red Hook Branch               40.675350
# 1356     3248                         LPI Facility                0.000000
# 1357     3215                        JSQ Don't Use                0.000000
# 1358     3480                         WS Don't Use                0.000000
# 1359     3197                         Hs Don't Use               40.719252
#
#       start station longitude
# 0                  -73.971146
# ...

# %%
# Convert the Lat/Long degress in Radians
ride_stations_df['lat'] = np.radians(ride_stations_df['start station latitude'])
ride_stations_df['long'] = np.radians(ride_stations_df['start station longitude'])

# %%
# Scipy get_metrics()
dist = DistanceMetric.get_metric('manhattan')

# %%
ride_stations_df[['lat','long']].to_numpy()
# Out:
# array([[ 0.71211778, -1.29104004],
#        [ 0.710712  , -1.29075558],
#        [ 0.71159524, -1.29073236],
#        ...,
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.        ],
#        [ 0.71068501, -1.29214114]])

# %%
dist.pairwise(ride_stations_df [['lat','long']].to_numpy())*6373
# Out:
# array([[0.00000000e+00, 1.07719213e+01, 5.29101229e+00, ...,
#         1.27661248e+04, 1.27661248e+04, 1.61483401e+01],
#        [1.07719213e+01, 0.00000000e+00, 5.77689602e+00, ...,
#         1.27553529e+04, 1.27553529e+04, 9.00220524e+00],
#        [5.29101229e+00, 5.77689602e+00, 0.00000000e+00, ...,
#         1.27608338e+04, 1.27608338e+04, 1.47791013e+01],
#        ...,
#        [1.27661248e+04, 1.27553529e+04, 1.27608338e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 1.27640111e+04],
#        [1.27661248e+04, 1.27553529e+04, 1.27608338e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 1.27640111e+04],
#        [1.61483401e+01, 9.00220524e+00, 1.47791013e+01, ...,
#         1.27640111e+04, 1.27640111e+04, 0.00000000e+00]])

# %%
ride_stations_df
# Out:
#       dock_id                   start station name  start station latitude  \
# 0        3331              Riverside Dr & W 104 St               40.801343
# 1        3101                N 12 St & Bedford Ave               40.720798
# 2        3140                      1 Ave & E 78 St               40.771404
# 3         236                  St Marks Pl & 2 Ave               40.728419
# 4        3427             Lafayette St & Jersey St               40.724305
# ...       ...                                  ...                     ...
# 1355     3252  Bike The Branches - Red Hook Branch               40.675350
# 1356     3248                         LPI Facility                0.000000
# 1357     3215                        JSQ Don't Use                0.000000
# 1358     3480                         WS Don't Use                0.000000
# 1359     3197                         Hs Don't Use               40.719252
#
#       start station longitude       lat      long
# ...

# %%
Distance3 = pd.DataFrame(dist.pairwise(ride_stations_df[['lat','long']].to_numpy())*6373, columns=ride_stations_df.dock_id.unique(), index=ride_stations_df.dock_id.unique())

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
Distance3 = Distance3.sort_index()

# %%
Distance3.to_csv("../data/distance3.csv")

# %%
stations['dock_id'].nunique()
# Out:
# 788

# %%
stations2 = stations[['dock_id', '_lat', '_long']]

# %%
stations2 = stations2.drop_duplicates(subset = ['dock_id'])

# %%
stations2['dock_id'] = stations2['dock_id'].astype(str)

# %%
stations2.dtypes
# Out:
# dock_id     object
# _lat       float64
# _long      float64
# dtype: object

# %%
# Convert the Lat/Long degress in Radians
stations2['_lat'] = np.radians(stations2['_lat'])
stations2['_long'] = np.radians(stations2['_long'])

# %%
# Scipy get_metrics()
dist = DistanceMetric.get_metric('manhattan')

# %%
stations2[['_lat','_long']].to_numpy()
# Out:
# array([[ 0.71152312, -1.29143769],
#        [ 0.71068264, -1.29166001],
#        [ 0.71054403, -1.29154653],
#        ...,
#        [ 0.71177058, -1.29011824],
#        [ 0.71229386, -1.29070376],
#        [ 0.71218438, -1.29075287]])

# %%
dist.pairwise(stations2 [['_lat','_long']].to_numpy())*6373
# Out:
# array([[ 0.        ,  6.77322946,  6.93340042, ...,  9.98588074,
#          9.58923515,  8.57848966],
#        [ 6.77322946,  0.        ,  1.60660371, ..., 16.7591102 ,
#         16.36246462, 15.35171912],
#        [ 6.93340042,  1.60660371,  0.        , ..., 16.91928116,
#         16.52263558, 15.51189008],
#        ...,
#        [ 9.98588074, 16.7591102 , 16.91928116, ...,  0.        ,
#          7.06643131,  6.68168731],
#        [ 9.58923515, 16.36246462, 16.52263558, ...,  7.06643131,
#          0.        ,  1.01074549],
#        [ 8.57848966, 15.35171912, 15.51189008, ...,  6.68168731,
#          1.01074549,  0.        ]])

# %%
Distance = pd.DataFrame(dist.pairwise(stations2[['_lat','_long']].to_numpy())*6373, columns=stations2.dock_id.unique(), index=stations2.dock_id.unique())

# %%
Distance.to_csv("../Data/distance.csv")

# %%
Distance
# Out:
#              72         79         82         83        116        119  \
# 72     0.000000   6.773229   6.933400  11.239997   3.677703   9.685671
# 79     6.773229   0.000000   1.606604   7.300459   3.095526   5.746133
# 82     6.933400   1.606604   0.000000   5.693855   3.552013   4.139529
# 83    11.239997   7.300459   5.693855   0.000000   9.245869   1.554326
# 116    3.677703   3.095526   3.552013   9.245869   0.000000   7.691543
# ...         ...        ...        ...        ...        ...        ...
# 3530  10.100892  16.874122  17.034293  17.424265  13.778596  16.250567
# 3531  10.008349  16.781579  16.941750  17.331721  13.686052  16.158024
# 3532   9.985881  16.759110  16.919281  17.309253  13.663584  16.135556
# 3533   9.589235  16.362465  16.522636  16.912607  13.266938  15.738910
# 3534   8.578490  15.351719  15.511890  15.901862  12.256193  14.728165
#
#             120        127        128       137  ...       3525       3526  \
# ...

# %%
stations.dtypes
# Out:
# dock_id          int64
# dock_name       object
# date            object
# hour             int64
# minute           int64
# avail_bikes      int64
# avail_docks      int64
# tot_docks        int64
# _lat           float64
# _long          float64
# in_service       int64
# status_key      object
# dock_status     object
# time            object
# dayofweek        int64
# dayofweek2      object
# season          object
# dtype: object

# %%
stations[stations['dock_id'] == 72]
# Out:
#           dock_id         dock_name        date  hour  minute  avail_bikes  \
# 0              72  W 52 St & 11 Ave  2015-03-01     1       6            8
# 1              72  W 52 St & 11 Ave  2015-03-01     1      16            8
# 2              72  W 52 St & 11 Ave  2015-03-01     1      25            8
# 3              72  W 52 St & 11 Ave  2015-03-01     1      35            8
# 4              72  W 52 St & 11 Ave  2015-03-01     1      45            8
# ...           ...               ...         ...   ...     ...          ...
# 30916806       72  W 52 St & 11 Ave  2019-03-31    16      26           45
# 30916807       72  W 52 St & 11 Ave  2019-03-31    17      26           44
# 30916808       72  W 52 St & 11 Ave  2019-03-31    18      49           49
# 30916809       72  W 52 St & 11 Ave  2019-03-31    20      30           53
# 30916810       72  W 52 St & 11 Ave  2019-03-31    24      35           47
#
# ...
